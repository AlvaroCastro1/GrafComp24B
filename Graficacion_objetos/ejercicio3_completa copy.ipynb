# %% [markdown]
# # Universidad Autonoma del Estado de México
# ## Centro universitario UAEM Zumpango
#
# # Ingenieria en computacion
# ## Graficacion computacional
# **Alumno:** Alvaro Jesus Castro Pizaña
#
# Fecha: 30 de septiembre del 2024
#
# mostrar triangulacion

# %%
# definimos los rangos
x1=0
x2=30

y1=0
y2=25

#Definir ejes
plt.axis([x1,x2,y1,y2])

plt.xticks(range(x1, x2+1, 1))  # Escala del eje x
plt.yticks(range(y1, y2+1, 1))  # Escala del eje y

plt.grid(True)
plt.title("Primera parte de la figura")

dx = dy = 2


x = [4, 7, 5, 6, 9, 8, 9, 12, 11, 14, 17, 15, 17, 22, 21, 24, 27, 29, 27, 25, 22, 21, 23, 25, 28, 26, 23, 24, 19, 16, 19, 20, 15, 11, 10, 8, 11, 12, 10, 7, 4 ]
y = [10, 13, 16, 19, 20, 18, 16, 18, 20, 21, 20, 18, 16, 17, 19, 21, 20, 22, 17, 17, 14, 11, 11, 13, 11, 9, 9, 6, 7, 9, 10, 13, 14, 14, 12, 11, 9, 7, 6, 8, 10 ]

plt.fill(
    [9, 6, 8],
    [20, 19, 18],
    alpha=0.6
)

plt.fill(
    [8, 6, 5],
    [18, 19, 16],
    alpha=0.6
)

plt.fill(
    [8, 5, 9],
    [18, 16, 16],
    alpha=0.6
)

plt.fill(
    [9, 5, 7],
    [16, 16, 13],
    alpha=0.6
)

plt.fill(
    [7, 10, 9],
    [13, 12, 16],
    alpha=0.6
)

plt.fill(
    [10, 7, 8 ],
    [12, 13, 11],
    alpha=0.6
)

plt.fill(
    [8, 7, 4 ],
    [11, 13, 10],
    alpha=0.6
)

plt.fill(
    [8, 7, 4 ],
    [11, 8, 10],
    alpha=0.6
)

plt.fill(
    [8, 11, 7 ],
    [11, 9, 8],
    alpha=0.6
)

plt.fill(
    [11, 10, 7 ],
    [9, 6, 8],
    alpha=0.6
)

plt.fill(
    [11, 10, 12 ],
    [9, 6, 7],
    alpha=0.6
)

plt.fill(
    [9, 10, 11 ],
    [16, 12, 14],
    alpha=0.6
)

plt.fill(
    [9, 10, 11 ],
    [16, 12, 14],
    alpha=0.6
)

plt.fill(
    [11, 9, 12],
    [14, 16, 18],
    alpha=0.6
)

plt.fill(
    [11, 12, 15],
    [14, 18, 14],
    alpha=0.7
)

plt.fill(
    [15, 15, 12],
    [14, 18, 18],
    alpha=0.7
)

plt.fill(
    [15, 15, 17],
    [14, 18, 16],
    alpha=0.7
)

plt.fill(
    [15, 17, 20],
    [14, 16, 13],
    alpha=0.7
)

plt.fill(
    [12, 11, 14],
    [18, 20, 21],
    alpha=0.7
)

plt.fill(
    [12, 14, 15],
    [18, 21, 18],
    alpha=0.7
)

plt.fill(
    [14, 15, 17],
    [21, 18, 20],
    alpha=0.7
)

plt.fill(
    [17, 20, 22],
    [16, 13, 17],
    alpha=0.7
)

plt.fill(
    [20, 22, 22],
    [13, 17, 14],
    alpha=0.7
)

plt.fill(
    [29, 27, 27],
    [22, 20, 17],
    alpha=0.7
)

plt.fill(
    [24, 25, 27],
    [21, 17, 17],
    alpha=0.7
)

plt.fill(
    [22, 24, 27],
    [17, 21, 17],
    alpha=0.7
)

plt.fill(
    [20, 21, 19],
    [13, 11, 10],
    alpha=0.7
)

plt.fill(
    [19, 23, 21],
    [10,  9, 11],
    alpha=0.7
)

plt.fill(
    [23, 28, 26],
    [11, 11, 9],
    alpha=0.7
)

plt.fill(
    [16, 23, 19],
    [9, 9, 7],
    alpha=0.7
)

plt.fill(
    [23, 23, 26],
    [9, 11, 9],
    alpha=0.7
)
plt.plot(x, y)


plt.show()
