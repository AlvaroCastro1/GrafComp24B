# %% [markdown]
# # Universidad Autonoma del Estado de México
# ## Centro universitario UAEM Zumpango
#
# # Ingenieria en computacion
# ## Graficacion computacional
# **Alumno:** Alvaro Jesus Castro Pizaña
#
# Fecha: 30 de septiembre del 2024
#
# mostrar triangulacion

# %% [markdown]
# ![image.png](attachment:c1111fd0-d3f7-4832-aaa8-c84d9c598a9f.png)
# **Hasta aqui mi avance**

# %%
# añadimos las librerias necesarias
import numpy as np
import matplotlib.pyplot as plt

# %%
# definimos los rangos
x1=-10
x2=10

y1=-10
y2=10

#Definir ejes
plt.axis([x1,x2,y1,y2])
plt.grid(True)
plt.title("Primera parte de la figura")

dx = dy = 2

# colocamos cada uno de los vectores
plt.arrow(0,0,0.5,1, head_length=0.1, head_width=0, color="k")
plt.arrow(0.5,1,2,0.5, head_length=0.1, head_width=0, color="r")
plt.arrow(2.5,1.5,-1,-1, head_length=0.1, head_width=0, color="k")
plt.arrow(1.5,0.5,0.6,-0.5, head_length=0.1, head_width=0, color="r")
plt.arrow(0,0,2,-1.8, head_length=0.1, head_width=0, color="k")
plt.arrow(2,-1.8, -2,-1,  head_length=0.1, head_width=0, color="r")
plt.arrow(0,-3, 2,-2,  head_length=0.1, head_width=0, color="k")
plt.arrow(2,-5, 3, -1.5,  head_length=0.1, head_width=0, color="r")
plt.arrow(5,-6.5, 2, 1.5,  head_length=0.1, head_width=0, color="k")
plt.arrow(7,-5, -1, 1.5,  head_length=0.1, head_width=0, color="r")
plt.arrow(6,-3.5, -3, 1.2,  head_length=0.1, head_width=0, color="k")
plt.arrow(3, -2, -1, 2, head_length=0.1, head_width=0, color="r")

# %%
# definimos los rangos
x1=-3
x2=8

y1=3
y2=-8

#Definir ejes
plt.axis([x1,x2,y1,y2])
plt.grid(True)
plt.title("Primera parte de la figura")

dx = dy = 2

# colocamos cada uno de los vectores
plt.arrow(0,0,0.5,1, head_length=0.1, head_width=0, color="k")
plt.arrow(0.5,1,2,0.5, head_length=0.1, head_width=0, color="r")
plt.arrow(2.5,1.5,-1,-1, head_length=0.1, head_width=0, color="k")
plt.arrow(1.5,0.5,0.6,-0.5, head_length=0.1, head_width=0, color="r")
plt.arrow(0,0,2,-1.8, head_length=0.1, head_width=0, color="k")
plt.arrow(2,-1.8, -2,-1,  head_length=0.1, head_width=0, color="r")
plt.arrow(0,-3, 2,-2,  head_length=0.1, head_width=0, color="k")
plt.arrow(2,-5, 3, -1.5,  head_length=0.1, head_width=0, color="r")
plt.arrow(5,-6.5, 2, 1.5,  head_length=0.1, head_width=0, color="k")
plt.arrow(7,-5, -1, 1.5,  head_length=0.1, head_width=0, color="r")
plt.arrow(6,-3.5, -3, 1.2,  head_length=0.1, head_width=0, color="k")
plt.arrow(3, -2, -1, 2, head_length=0.1, head_width=0, color="r")

plt.fill(
    [0, 0.5, 2.5, 0],
    [0, 1, 1.5, 0],
    alpha=0.9
)

plt.fill(
    [2.5, 0, 1.5, 2.5],
    [1.5, 0, 0.5, 1.5],
    alpha=0.9
)

plt.fill(
    [0,2,1.5,0],
    [0,-2,0.5,0],
    alpha=0.9
)

plt.fill(
    [2, 2, 1.5,2],
    [-2, 0, 0.5, -2],
    alpha=0.9
)

plt.fill(
    [2, 3, 2, 2 ],
    [-2, -2, 0, -2],
    alpha=0.9
)

plt.fill(
    [3, 0, 2, 3],
    [-2, -2.9, -1.9, -2],
    alpha=0.9
)

plt.fill(
    [3, 0, 2, 3],
    [-2, -2.9, -1.9, -2],
    alpha=0.9
)

plt.fill(
    [0, 2, 3, 0],
    [-2.9, -5, -2, -2.9],
    alpha=0.9
)

plt.fill(
    [2, 3, 0],
    [-5, -2, -2.9],
    alpha=0.9
)

plt.fill(
    [2, 3, 6, 2],
    [-5, -2, -3.5, -5],
    alpha=0.9
)

plt.fill(
    [2, 6, 7, 2],
    [-5, -3.5, -5, -5], 
    alpha=0.9
)

plt.fill(
    [2, 7, 5, 2],
    [-5, -5, -6.5, -5],
    alpha = 0.9
)
plt.show()
